# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from scipy import stats

# %%
# This cell previously had a syntax error. Updating it to point to the correct path.
path = '/content/SampleSuperstore.csv'
print(f"Path set to: {path}")
# Out:
# Path set to: /content/SampleSuperstore.csv

# %%
import os
print(os.listdir('/content/'))
# Out:
# ['.config', 'SampleSuperstore.csv', 'sample_data']

# %%
print(df.head())
# Out:
#   Order ID  Order Date         Category Sub-Category       State   Region  \
# 0  CA-1001  2024-02-22       Technology       Laptop    Illinois     East
# 1  CA-1002  2024-10-14       Technology        Phone       Texas    South
# 2  CA-1003  2024-12-23        Furniture        Table     Florida  Central
# 3  CA-1004  2024-07-13  Office Supplies        Paper  California  Central
# 4  CA-1005  2024-07-12  Office Supplies          Pen  California  Central
#
#      Sales  Quantity  Discount  Profit
# 0    69.52         4       0.1   -4.34
# 1    82.93         4       0.0  -12.70
# 2  1186.75         1       0.1  242.95
# 3   446.32         2       0.0   81.12
# 4   543.75         8       0.0  -96.94

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      100 non-null    object
#  1   Order Date    100 non-null    object
#  2   Category      100 non-null    object
#  3   Sub-Category  100 non-null    object
#  4   State         100 non-null    object
#  5   Region        100 non-null    object
#  6   Sales         100 non-null    float64
#  7   Quantity      100 non-null    int64
#  8   Discount      100 non-null    float64
#  9   Profit        100 non-null    float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 7.9+ KB
# None

# %%
print(df.isnull().sum())
# Out:
# Order ID        0
# Order Date      0
# Category        0
# Sub-Category    0
# State           0
# Region          0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
print("Average Sales:", np.mean(df["Sales"]))
# Out:
# Average Sales: 1099.7875000000001

# %%
sales_by_category = df.groupby("Category")["Sales"].sum()

# %%
plt.figure(figsize=(8,5))
plt.bar(sales_by_category.index, sales_by_category.values)
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Sales"], bins=30, edgecolor="black")
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x="Sales", y="Profit", alpha=0.5)
plt.title("Sales vs Profit")
plt.show()

# %%
X_train, X_test = train_test_split(df, test_size=0.2, random_state=42)

# %%
print("Split completed successfully.")
print(f"Training Rows: {len(X_train)}")
print(f"Testing Rows: {len(X_test)}")
# Out:
# Split completed successfully.
# Training Rows: 80
# Testing Rows: 20

# %%
print("Mean Sales:", stats.tmean(df["Sales"]))
# Out:
# Mean Sales: 1099.7875000000001
